# %%
# !pip install -U "langchain[google-genai]"
# Out:
# Collecting langchain[google-genai]
#   Using cached langchain-1.2.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-core<2.0.0,>=1.2.1 (from langchain[google-genai])
#   Using cached langchain_core-1.2.5-py3-none-any.whl.metadata (3.7 kB)
# Collecting langgraph<1.1.0,>=1.0.2 (from langchain[google-genai])
#   Using cached langgraph-1.0.5-py3-none-any.whl.metadata (7.4 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain[google-genai])
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting langchain-google-genai (from langchain[google-genai])
#   Using cached langchain_google_genai-4.1.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Using cached langsmith-0.5.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /opt/homebrew/Caskroom/miniconda/base/envs/stat/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain[google-genai]) (25.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Downloading pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/homebrew/Caskroom/miniconda/base/envs/stat/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.1->langchain[google-genai]) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Using cached uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (1.1 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.2 (from langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Using cached langgraph_sdk-0.3.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Downloading xxhash-3.6.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Downloading ormsgpack-1.12.1-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl.metadata (3.2 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.10.1 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Downloading orjson-3.11.5-cp311-cp311-macosx_15_0_arm64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Using cached zstandard-0.25.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.3 kB)
# Collecting anyio (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Downloading anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting certifi (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain[google-genai])
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain[google-genai])
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3.0.0,>=2.7.4->langchain[google-genai])
#   Using cached pydantic_core-2.41.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain[google-genai])
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Using cached charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (37 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain[google-genai])
#   Downloading urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai->langchain[google-genai])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<2.0.0,>=1.56.0 (from langchain-google-genai->langchain[google-genai])
#   Using cached google_genai-1.56.0-py3-none-any.whl.metadata (53 kB)
# Collecting google-auth<3.0.0,>=2.45.0 (from google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai])
#   Using cached google_auth-2.45.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai])
#   Downloading websockets-15.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting distro<2,>=1.7.0 (from google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai])
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting sniffio (from google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai])
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai])
#   Downloading cachetools-6.2.4-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai])
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai])
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.45.0->google-auth[requests]<3.0.0,>=2.45.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai])
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached langchain-1.2.0-py3-none-any.whl (102 kB)
# Using cached langchain_core-1.2.5-py3-none-any.whl (484 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph-1.0.5-py3-none-any.whl (157 kB)
# Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.1-py3-none-any.whl (66 kB)
# Using cached langsmith-0.5.2-py3-none-any.whl (283 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-macosx_11_0_arm64.whl (1.9 MB)
# Downloading pyyaml-6.0.3-cp311-cp311-macosx_11_0_arm64.whl (175 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached uuid_utils-0.12.0-cp39-abi3-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (603 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading orjson-3.11.5-cp311-cp311-macosx_15_0_arm64.whl (129 kB)
# Downloading ormsgpack-1.12.1-cp311-cp311-macosx_10_12_x86_64.macosx_11_0_arm64.macosx_10_12_universal2.whl (376 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl (206 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading xxhash-3.6.0-cp311-cp311-macosx_11_0_arm64.whl (30 kB)
# Using cached zstandard-0.25.0-cp311-cp311-macosx_11_0_arm64.whl (640 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Using cached langchain_google_genai-4.1.2-py3-none-any.whl (65 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached google_genai-1.56.0-py3-none-any.whl (426 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached google_auth-2.45.0-py2.py3-none-any.whl (233 kB)
# Downloading cachetools-6.2.4-py3-none-any.whl (11 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading websockets-15.0.1-cp311-cp311-macosx_11_0_arm64.whl (173 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: filetype, zstandard, xxhash, websockets, uuid-utils, urllib3, typing-inspection, tenacity, sniffio, pyyaml, pydantic-core, pyasn1, ormsgpack, orjson, jsonpointer, idna, h11, distro, charset_normalizer, certifi, cachetools, annotated-types, rsa, requests, pydantic, pyasn1-modules, jsonpatch, httpcore, anyio, requests-toolbelt, httpx, google-auth, langsmith, langgraph-sdk, langchain-core, google-genai, langgraph-checkpoint, langchain-google-genai, langgraph-prebuilt, langgraph, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41/41 [langchain]41 [langchain-google-genai]
# Successfully installed annotated-types-0.7.0 anyio-4.12.0 cachetools-6.2.4 certifi-2025.11.12 charset_normalizer-3.4.4 distro-1.9.0 filetype-1.2.0 google-auth-2.45.0 google-genai-1.56.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jsonpatch-1.33 jsonpointer-3.0.0 langchain-1.2.0 langchain-core-1.2.5 langchain-google-genai-4.1.2 langgraph-1.0.5 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.3.1 langsmith-0.5.2 orjson-3.11.5 ormsgpack-1.12.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.12.5 pydantic-core-2.41.5 pyyaml-6.0.3 requests-2.32.5 requests-toolbelt-1.0.0 rsa-4.9.1 sniffio-1.3.1 tenacity-9.1.2 typing-inspection-0.4.2 urllib3-2.6.2 uuid-utils-0.12.0 websockets-15.0.1 xxhash-3.6.0 zstandard-0.25.0

# %%
# !pip install prettyprint
# Out:
# Requirement already satisfied: prettyprint in /opt/homebrew/Caskroom/miniconda/base/envs/stat/lib/python3.11/site-packages (0.1.5)

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "AIzaSyCw-bBtVTRZOklVVUHu1JROgFt71KD5Xto"

model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
response = model.invoke("Why do parrots talk?")

# %%
from pprint import pprint as pp

# %%
pp(response)
# Out:
# AIMessage(content='Parrots talk for a fascinating combination of reasons, driven by their **intelligence, social nature, and evolutionary adaptations.** It\'s not just about mimicking sounds; there\'s a lot more going on.\n\nHere are the primary reasons why parrots talk:\n\n**1. Social Bonding and Communication:**\n\n*   **Flock Dynamics:** In the wild, parrots live in large, complex social groups. They use a variety of vocalizations (squawks, calls, whistles) to communicate with each other for survival. This includes:\n    *   **Maintaining contact:** Keeping track of their flock members when flying or foraging.\n    *   **Warning of danger:** Alerting others to predators.\n    *   **Social grooming:** Vocalizations can be part of their bonding rituals.\n    *   **Courtship and mating:** Specific calls can be used to attract mates.\n*   **Mimicry as a Social Tool:** The ability to mimic sounds, including human speech, is thought to have evolved as a way to integrate into their social group. By mimicking the "language" of their flock, they become more accepted and can participate in social interactions more effectively. In a human household, they see you as their flock and try to communicate with you in a way they understand.\n\n**2. Intelligence and Cognitive Abilities:**\n\n*   **Problem-Solving and Learning:** Parrots are highly intelligent birds with excellent problem-solving skills and a strong capacity for learning. They can learn complex sequences, understand the meaning of some words, and even use language in novel ways.\n*   **Cognitive Stimulation:** Talking provides mental stimulation for parrots. They are curious creatures and enjoy figuring out how to produce sounds and associate them with actions or objects.\n\n**3. Evolutionary Advantage (in the wild):**\n\n*   **"Fuzzy" Communication:** While they have their own specific calls, the ability to mimic a wider range of sounds might have offered an evolutionary advantage by allowing them to blend in with their environment or even confuse predators. It\'s a form of "fuzzy" communication that can be adaptable.\n*   **Interacting with Different Species:** In some environments, they might interact with other species, and the ability to mimic could be beneficial in understanding or deterring them.\n\n**4. The "Echo" Effect (for human parrots):**\n\n*   **Attracting Attention and Rewards:** When a parrot is kept as a pet, the act of "talking" often elicits a positive reaction from its human caregivers – attention, praise, treats, and interaction. This reinforces the behavior, making the parrot more likely to repeat it. They learn that making certain sounds gets them what they want.\n*   **Curiosity about Novel Sounds:** Human environments are full of new and interesting sounds. Parrots are naturally curious and will try to replicate these sounds to understand them or to engage with them.\n\n**Important Nuances:**\n\n*   **Not "Understanding" Like Humans:** While some parrots can learn the meaning of words and use them contextually, they don\'t possess the same linguistic understanding as humans. They are not forming complex thoughts and sentences with the same intent. It\'s more about associative learning and mimicking patterns.\n*   **Individual Variation:** Not all parrots talk, and the extent to which they talk varies greatly by species and individual bird. Some species are known for their talking abilities (e.g., African Greys, Amazons, Budgies), while others are less inclined.\n*   **Motivation is Key:** A parrot that is well-stimulated, socialized, and feels secure in its environment is more likely to "talk" than one that is bored, stressed, or isolated.\n\nIn essence, parrots talk because they are intelligent, social beings who are wired to communicate and learn. When in a human environment, this innate ability is often amplified by the positive reinforcement they receive, leading them to mimic human speech as a way to bond, interact, and get attention.', additiona ...

# %%
# !pip install numpy
import numpy as np
# Out:
# Requirement already satisfied: numpy in /opt/homebrew/Caskroom/miniconda/base/envs/stat/lib/python3.11/site-packages (2.4.0)

# %%
class LinearRegressionFromScratch:
    def __init__(self):
        self.coefficients = None
        self.intercept = None

    def fit(self, X, y):
        # Add intercept column
        X_with_intercept = np.column_stack([np.ones(len(X)), X])

        # Normal equation: β = (X^T × X)^(-1) × X^T × y
        XtX = X_with_intercept.T @ X_with_intercept
        XtX_inv = np.linalg.inv(XtX)
        Xty = X_with_intercept.T @ y

        coeffs = XtX_inv @ Xty

        self.intercept = coeffs[0]
        self.coefficients = coeffs[1:]

    def predict(self, X):
        return self.intercept + X @ self.coefficients

# Example usage
X = np.array([[1], [2], [3], [4], [5]])  # Features
y = np.array([2, 4, 6, 8, 10])           # Target

model = LinearRegressionFromScratch()
model.fit(X, y)
predictions = model.predict(X)

# %%
from sklearn.linear_model import LinearRegression

# Create and train model
model = LinearRegression()
model.fit(X, y)

# Make predictions
predictions = model.predict(X)

# Get coefficients
print(f"Intercept: {model.intercept_}")
print(f"Coefficients: {model.coef_}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#       3 # Create and train model
#       4 model = LinearRegression()
#
# ModuleNotFoundError: No module named 'sklearn'
